# %% [markdown]
# <a href="https://colab.research.google.com/github/Khairnazfa/Khairnazfa/blob/main/Sentiment_Analysis_for_TripAdvisor_Hotels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis for TripAdvisor Reviews

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# ## Obtaining the Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/theleadio/datascience_demo/master/tripadvisor_hotel_reviews.csv')
df.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %% [markdown]
# ## Exploring the Data

# %% [markdown]
# ### Countplot

# %%
sns.set(style='white')
plt.figure(figsize=(10, 7))
sns.countplot(data=df, x='Rating', palette='mako')

# %% [markdown]
# Most of the comments have high ratings (4-5)

# %% [markdown]
# ### Word Cloud

# %%
def wordcloud_generator(data, title=None):
    wordcloud = WordCloud(width = 800, height = 800,
                          background_color ='white',
                          min_font_size = 10
                         ).generate(" ".join(data.values))
    
    # plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud, interpolation='bilinear') 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.title(title,fontsize=15)
    plt.show()

# %%
wordcloud_generator(df['Review'], title = 'Most used words in reviews\n')

# %%
for rating in range(1, 6):
  reviews = df[df['Rating'] == rating]
  wordcloud_generator(reviews['Review'], title='Most used words for rating ' + str(rating) + '\n')
  print('\n')

# %% [markdown]
# Seems like the most common words is 'hotel room' and it exists in all ratings so there could be mixed reviews of the rooms.

# %% [markdown]
# ## Results

# %% [markdown]
# ### Keyword 1: gym

# %%
query = 'gym'
query_tfidf = tfidf.transform([query])

cosims = cosine_similarity(query_tfidf, feature).flatten()
results = reversed(cosims.argsort()[:-6:-1])

for r in results:
  print(f"Similarity score: {cosims[r]:.5f}, \nReview: {df.iloc[r]['Review']}")
  print('-----')
# Out:
# Similarity score: 0.31639,
# Review: really great hotel, stay langham 4 nights july super, checked easily room really clean tidy, did eat breakfast hotel morning cost 70, expensive recieved.there turn service night chocolate left pillows, gym pool pool cold gym lovely, concierge extremely helpful, langham ideal place stay close local shops bars quiet,
# -----
# Similarity score: 0.34519,
# Review: great hotel-perfect location booked hotels.com got hotel great price, price went 3 times reimbursed lower price calling.this hotel perfect location-within walking distance, quiet hotel-we didnt hear loud noise street, continental breakfast average-it did job light breakfast, waffle maker make waffles, perfect light breakfast head large lunch, room clean spacious, bellman exceptional-friendly helpful.this hotel attached ritz use facilities, gym absolutely gorgeous, need gym, treadmills ellipticals piece gym equipment need, high quality, impressed.we definately stay trip,
# -----
# ...

# %% [markdown]
# ### Keyword 2: breakfast

# %%
query = 'breakfast'
query_tfidf = tfidf.transform([query])

cosims = cosine_similarity(query_tfidf, feature).flatten()
results = reversed(cosims.argsort()[:-6:-1])

for r in results:
  print(f"Similarity score: {cosims[r]:.5f}, \nReview: {df.iloc[r]['Review']}")
  print('-----')
# Out:
# Similarity score: 0.23139,
# Review: nice hotel good value good breakfast one-night stays february, enjoyed hotel highly recommend, breakfast standard european continental, enjoyed pizza little bar/cafe hotel,
# -----
# Similarity score: 0.23148,
# Review: comfortable stay room comfortable clean, breakfast ample belgian waffles make, breakfast room small tables close, lack parking space,
# -----
# Similarity score: 0.23818,
# ...

# %% [markdown]
# ### Keyword 3: customer service

# %%
query = 'customer service'
query_tfidf = tfidf.transform([query])

cosims = cosine_similarity(query_tfidf, feature).flatten()
results = reversed(cosims.argsort()[:-6:-1])

for r in results:
  print(f"Similarity score: {cosims[r]:.5f}, \nReview: {df.iloc[r]['Review']}")
  print('-----')
# Out:
# Similarity score: 0.35664,
# ...

# %% [markdown]
# ### Keyword 4: wi-fi

# %%
query = 'wi-fi'
query_tfidf = tfidf.transform([query])

cosims = cosine_similarity(query_tfidf, feature).flatten()
results = reversed(cosims.argsort()[:-6:-1])

for r in results:
  print(f"Similarity score: {cosims[r]:.5f}, \nReview: {df.iloc[r]['Review']}")
  print('-----')
# Out:
# Similarity score: 0.31767,
# Review: great place, just left marriott yesetrday 5 great days, n't understand negative complaints, people just need gripe, yeah large whattaya expect marriott waikiki beach, staff friendly rooms environs notch neat clean views ocean room outstanding, stayed sheraton waikiki hilton hawaiian village heard sheraton need work appears undergoing right hilton absolutely outstanding little removed main waikiki n't like walk dark daughters, gripe marriott wi-fi access, did n't work room 10.95 day, sitting lobby turtle bay resort north shore looking surf free wi-fi 12 day resort fee includes parking tennis snorkle gear, leave impressions tbr heading trip far good,
# -----
# Similarity score: 0.33494,
# ...

# %% [markdown]
# ### Keyword 5: swimming pool

# %%
query = 'swimming pool'
query_tfidf = tfidf.transform([query])

cosims = cosine_similarity(query_tfidf, feature).flatten()
results = reversed(cosims.argsort()[:-6:-1])

for r in results:
  print(f"Similarity score: {cosims[r]:.5f}, \nReview: {df.iloc[r]['Review']}")
  print('-----')
# Out:
# Similarity score: 0.25981,
# Review: best hotel ubud brilliant hotel, swimming pool amazing service perfect view amazing enjoy, 1 tip book restaurant mozaique good gastronomic,
# -----
# Similarity score: 0.26424,
# Review: excellent hotel simply great staff extremely kind charming rooms beautiful extra clean spa great maybe little bit overpriced swimming pool area unbeliavle, singapore truly say best hotel stayed,
# -----
# Similarity score: 0.28039,
# Review: great hotel stayed hotel tour group, hotel beautiful clean, food restaurants good good selection, staff friendly helpful not spoke english, hotel located city center cab ride downtown 8 10, quiet large indoor swimming pool, definitely stay,
# -----
# Similarity score: 0.32119,
# Review: meet dallas nice outdoor swimming pool outside, rooms big, lobby large hold people, met america family,
# -----
# Similarity score: 0.33476,
# ...

# %% [markdown]
# ### Keyword 6: room

# %%
query = 'room'
query_tfidf = tfidf.transform([query])

cosims = cosine_similarity(query_tfidf, feature).flatten()
results = reversed(cosims.argsort()[:-6:-1])

for r in results:
  print(f"Similarity score: {cosims[r]:.5f}, \nReview: {df.iloc[r]['Review']}")
  print('-----')
# Out:
# Similarity score: 0.29939,
# Review: nice hotel view second room room left row,
# -----
# Similarity score: 0.30086,
# Review: worst, impression looked ok. room n't ready check normal, desk girl alexis not friendly negative, room came search rear hotel elevator, entering room stale air stench overpowering, room old price 400 euros, starwood embarrassed, hotels stayed, room old worn, small flies room, weathered, checked did n't spend 15 minutes room, showed room just bad not clean, moved amstel hotel true 5 star,
# -----
# Similarity score: 0.31935,
# ...

# %% [markdown]
# ## Analyzing Sentiment Intensity

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
sentiments = [analyzer.polarity_scores(review)['compound'] for review in df['Review']]

# %%
 # creating a new column in 'df' with sentiment intensity scores

df['Sentiments'] = sentiments

# %%
df.head()
# Out:
#                                               Review  Rating  Sentiments
# 0  nice hotel expensive parking got good deal sta...       4      0.9747
# 1  ok nothing special charge diamond member hilto...       2      0.9787
# 2  nice rooms not 4* experience hotel monaco seat...       3      0.9889
# 3  unique, great stay, wonderful time hotel monac...       5      0.9912
# 4  great stay great stay, went seahawk game aweso...       5      0.9797

# %%
# reviews with high ratings but negative sentiments

pd.set_option('display.max_colwidth', None)
df[(df['Rating'] == 5) & (df['Sentiments'] < 0)].sort_values('Sentiments')[0:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# reviews with low ratings but positive sentiments

df[(df['Rating'] == 1) & (df['Sentiments'] > 0)].sort_values('Sentiments', ascending=False)[0:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
